# %%
import mytools
import pandas as pd

# %%
df1 = pd.read_csv(R'csv.csv', encoding='GBK')

# %%
tau_y = mytools.goodmanKruska_tau_y(df1,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.23253397282174276

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '弱相关'

# %%
mytools.绘制单个类别变量饼图(df1,'父亲职业重新编码')

# %%
mytools.制作交叉表(df1,'母亲职业重新编码','父亲职业重新编码')
# Out:
# 父亲职业重新编码   个体  事业单位       公务员        国企  家庭主妇  家庭父亲        民企       All
# 母亲职业重新编码
#  公务员      0.0   0.0  0.055556  0.000000   0.0   0.0  0.000000  0.020408
# 上市公司      0.0   0.0  0.000000  0.000000   0.0   0.0  0.142857  0.020408
# 个体        0.4   0.2  0.055556  0.166667   0.0   0.0  0.000000  0.142857
# 事业单位      0.0   0.6  0.444444  0.166667   0.0   1.0  0.000000  0.265306
# 公务员       0.1   0.0  0.388889  0.000000   0.0   0.0  0.285714  0.204082
# 国企        0.0   0.0  0.055556  0.166667   0.0   0.0  0.000000  0.040816
# 家庭主妇      0.4   0.0  0.000000  0.333333   1.0   0.0  0.428571  0.224490
# 无         0.1   0.0  0.000000  0.000000   0.0   0.0  0.000000  0.020408
# 民企        0.0   0.2  0.000000  0.166667   0.0   0.0  0.142857  0.061224
